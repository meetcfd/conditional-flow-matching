# %%
# %env CUDA_VISIBLE_DEVICES = 0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# %load_ext autoreload
# %autoreload 2
import sys; 
sys.path.extend(['/home/meet/FlowMatchingTests/conditional-flow-matching/'])

import matplotlib.pyplot as plt
import numpy as np
import torch
from torchcfm.conditional_flow_matching import *
from physics_flow_matching.unet.unet_bb import UNetModelWrapper as UNetModel
from torchdiffeq import odeint
from einops import rearrange

# %%
# data_0_150 = np.load('/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_u_y5-150_41-220_out.npy')

# %%
data = [np.load('/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_wall_dudy_all_out.npy')] #, data_0_150[:, :1]
for i in [5, 10, 40, 60, 70, 80, 100, 150]:
    data.append(np.load(f'/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_u_y{i}_all_out.npy'))
data = np.concatenate(data, axis=1)

# %%
m_, std_ = data[:36000].mean(axis=(0,2,3), keepdims=True), data[:36000].std(axis=(0,2,3), keepdims=True)

# %%
# m_, std_  = m_[:, [0, 1, 4, 6, 7, 8]], std_[:, [0, 1, 4, 6, 7, 8]]

# %%
# test_data_0_150 = np.load('/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_u_y5-150_221-259_out.npy')

# %%
# test_data = [np.load('/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_wall_dudy_221-259_out.npy')[:, None], test_data_0_150[:, :1]]
# for i in ["60-80-100"]:
#     test_data.append(np.load(f'/home/xiantao/case/wall_pressure/bigchannel/data/to_meet/channel_180_u_y{i}_221-259_out.npy'))
# test_data.append(test_data_0_150[:, 1:])
# test_data = np.concatenate(test_data, axis=1)

# %%
X = (data[36000:39900] - m_)/std_

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
exp=3
iteration = 30
ot_cfm_model = UNetModel(dim=[1, 160, 200],
                         num_channels=128,
                         out_channels=1,
                         num_res_blocks=2,
                         num_head_channels=64,
                         attention_resolutions="40, 20",
                         dropout=0.0,
                         use_new_attention_order=True,
                         use_scale_shift_norm=True)
state = torch.load(f"/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_{exp}/saved_state/checkpoint_{iteration}.pth")
ot_cfm_model.load_state_dict(state["model_state_dict"])
ot_cfm_model.to(device)
ot_cfm_model.eval();
# Out:
# /tmp/ipykernel_3835965/2667189149.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(f"/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_{exp}/saved_state/checkpoint_{iteration}.pth")

# %%
batch_size=10
ind = 0

# %%
samples_list = []
for batch in range(X.shape[0]//batch_size):
    each_samples_list =[]
    with torch.no_grad():
        for i in range(8-ind): #for i in range(1):
            if i == 0:
                out = ot_cfm_model(torch.tensor(X[batch*batch_size:(batch+1)*batch_size, ind:ind+1], device=device)).detach().cpu().numpy()
            else:
                out = ot_cfm_model(torch.tensor(out, device=device)).detach().cpu().numpy()
            sout = out*std_[:, ind+i+1:ind+i+2]
            sout += m_[:, ind+i+1:ind+i+2]
            each_samples_list.append(sout)
    samples_list.append(each_samples_list)

# %%
# samples_list = []
# for batch in range(X.shape[0]//batch_size):
#     with torch.no_grad():
#         out = ot_cfm_model(torch.tensor(X[batch*batch_size:(batch+1)*batch_size, ind:ind+1], device=device)).detach().cpu().numpy()
#     out *= std_[:, ind+1:ind+2]
#     out += m_[:, ind+1:ind+2]
#     samples_list.append(out)
# Out:
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/multiarray.py", line 1, in <module>
#     from numpy._core import multiarray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.core.fromnumeric failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.core.arrayprint failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 2, in __getattr__
#     from numpy._core import numerictypes
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numerictypes.py", line 82, in <module>
#     from . import multiarray as ma
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.core.numeric failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.core.records failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 2, in __getattr__
#     from numpy._core import numerictypes
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numerictypes.py", line 82, in <module>
#     from . import multiarray as ma
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.core.getlimits failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 2, in __getattr__
#     from numpy._core import numerictypes
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numerictypes.py", line 82, in <module>
#     from . import multiarray as ma
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.core._internal failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_internal.py", line 1, in <module>
#     from numpy._core import _internal
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/_internal.py", line 14, in <module>
#     from .multiarray import dtype, array, ndarray, promote_types, StringDType
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.core failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.lib.mixins failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 2, in __getattr__
#     from numpy._core import numerictypes
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numerictypes.py", line 82, in <module>
#     from . import multiarray as ma
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.lib.stride_tricks failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/stride_tricks.py", line 1, in <module>
#     from ._stride_tricks_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_stride_tricks_impl.py", line 14, in <module>
#     from numpy._core.numeric import normalize_axis_tuple
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
# RuntimeError: empty_like method already has a different docstring
# ]
# /home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_scalars.py:12: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   _BoolLike_co: TypeAlias = bool | np.bool
# [autoreload of numpy._typing._scalars failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_scalars.py", line 12, in <module>
#     _BoolLike_co: TypeAlias = bool | np.bool
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/__init__.py", line 324, in __getattr__
#     warnings.filterwarnings("ignore", message="numpy.ndarray size changed")
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations. Did you mean: 'bool_'?
# ]
# /home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_dtype_like.py:141: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   | type[np.bool]
# [autoreload of numpy._typing._dtype_like failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_dtype_like.py", line 141, in <module>
#     | type[np.bool]
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/__init__.py", line 324, in __getattr__
#     warnings.filterwarnings("ignore", message="numpy.ndarray size changed")
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations. Did you mean: 'bool_'?
# ]
# /home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_array_like.py:97: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   dtype[np.bool],
# [autoreload of numpy._typing._array_like failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_typing/_array_like.py", line 97, in <module>
#     dtype[np.bool],
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/__init__.py", line 324, in __getattr__
#     warnings.filterwarnings("ignore", message="numpy.ndarray size changed")
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations. Did you mean: 'bool_'?
# ]
# [autoreload of numpy.linalg failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/linalg/linalg.py", line 3, in __getattr__
#     from numpy.linalg import _linalg
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/linalg/_linalg.py", line 25, in <module>
#     from numpy._core import (
# ImportError: cannot import name 'array' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.matrixlib.defmatrix failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/matrixlib/defmatrix.py", line 8, in <module>
#     import numpy._core.numeric as N
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.lib.format failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/format.py", line 170, in <module>
#     from numpy.lib._utils_impl import drop_metadata
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_utils_impl.py", line 10, in <module>
#     from numpy._core import ndarray
# ImportError: cannot import name 'ndarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.lib._iotools failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_iotools.py", line 7, in <module>
#     import numpy._core.numeric as nx
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.lib.npyio failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/npyio.py", line 1, in <module>
#     from ._npyio_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py", line 20, in <module>
#     from numpy._core.multiarray import packbits, unpackbits
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/__init__.py", line 13, in <module>
#     from . import array_utils
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.fft._pocketfft failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/fft/_pocketfft.py", line 36, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.fft failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/fft/helper.py", line 3, in __getattr__
#     from numpy.fft import _helper
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/fft/_helper.py", line 5, in <module>
#     from numpy._core import integer, empty, arange, asarray, roll
# ImportError: cannot import name 'integer' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.polyutils failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/polyutils.py", line 27, in <module>
#     from numpy._core.multiarray import dragon4_positional, dragon4_scientific
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.polynomial.polynomial failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/polynomial.py", line 85, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.chebyshev failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/chebyshev.py", line 112, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.legendre failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/legendre.py", line 84, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.hermite failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/hermite.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.hermite_e failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/hermite_e.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.laguerre failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/polynomial/laguerre.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.ctypeslib failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/ctypeslib.py", line 59, in <module>
#     from numpy._core.multiarray import _flagdict, flagsobj
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.ma.extras failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/ma/extras.py", line 35, in <module>
#     from numpy.lib.array_utils import normalize_axis_index, normalize_axis_tuple
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/core/defchararray.py", line 2, in __getattr__
#     from numpy._core import defchararray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/defchararray.py", line 22, in <module>
#     from .numerictypes import bytes_, str_, character
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/numerictypes.py", line 82, in <module>
#     from . import multiarray as ma
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]
# /home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/PIL/Image.py:119: RuntimeWarning: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 10.4.0
# Pillow version: 11.0.0
#   warnings.warn(str(v), RuntimeWarning)
# [autoreload of PIL.Image failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/PIL/Image.py", line 105, in <module>
#     raise ImportError(msg)
# ImportError: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 10.4.0
# Pillow version: 11.0.0
# ]
# [autoreload of numpy._core failed: Traceback (most recent call last):
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/__init__.py", line 23, in <module>
#     from . import multiarray
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/multiarray.py", line 83, in <module>
#     def empty_like(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 178, in decorator
#     return array_function_dispatch(
#   File "/home/meet/.conda/envs/torchcfm/lib/python3.10/site-packages/numpy/_core/overrides.py", line 158, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a different docstring
# ]

# %%
sample_list2 = [np.concatenate(sample, axis=1) for sample in samples_list]
samples = np.concatenate(sample_list2)

# %%
samples.shape
# Out:
# (3900, 8, 320, 200)

# %%
np.save(f"/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_{exp}/samples_{iteration}epch_rl=3", samples)

# %%
# for j in range(0, 1):
#     for i in range(0,8):
#         fig, axes = plt.subplots(nrows=1, ncols=4, dpi=200)
#         if i == 0:
#             ax = axes[0].imshow(data[j+36000,ind])
#             plt.colorbar(ax,ax=axes[0])
#         else:
#             ax = axes[0].imshow(samples[j,i-1])
#             plt.colorbar(ax,ax=axes[0])
#         ax = axes[1].imshow(samples[j,i])
#         plt.colorbar(ax,ax=axes[1])
#         ax= axes[2].imshow(data[j+36000, i+1])
#         plt.colorbar(ax,ax=axes[2])
#         ax = axes[3].imshow(np.abs(samples[j,i] - data[j+36000, i+1]))
#         plt.colorbar(ax,ax=axes[3])

# %%
# samples_10_40 = np.load('/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_1/samples_5epch_10_40.npy')[:, None]
# samples_40_60 = np.load('/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_1/samples_5epch_40_60.npy')[:, None]
# samples_70_80 = np.load('/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_1/samples_5epch_70_80.npy')[:, None]
# samples_80_100 = np.load('/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_1/samples_5epch_80_100.npy')[:, None]

# %%
mean_error = np.mean(np.abs(samples[:, 0] - data[36000:39900, ind+1]), axis=(1,2))

# %%
# mean_error_1 = np.mean(np.abs(samples_80_100[:, 0] - data[36000:39900, 7]), axis=(1,2))
# mean_error_3 = np.mean(np.abs(samples_10_40[:, 0] - data[36000:39900, 3]), axis=(1,2))
# mean_error_2 = np.mean(np.abs(samples_40_60[:, 0] - data[36000:39900, 4]), axis=(1,2))
# mean_error_4 = np.mean(np.abs(samples_70_80[:, 0] - data[36000:39900, 6]), axis=(1,2))

# %%
# plt.plot(mean_error_1, label="80-100")
# plt.plot(mean_error_4, label="70-80")
# plt.plot(mean_error_2, label="40-60")
# plt.plot(mean_error_3, label="10-40")
plt.plot(mean_error, label="100-150")
plt.legend()

# %%
# for i in range(1):
#     fig, axes = plt.subplots(nrows=1, ncols=4, dpi=500, figsize=(20,10))
#     ax = axes[0].imshow(X[7800+i,ind])
#     plt.colorbar(ax,ax=axes[0])
#     ax = axes[1].imshow(samples[i,0])
#     plt.colorbar(ax,ax=axes[1])
#     ax= axes[2].imshow(data[7800+i, ind+1])
#     plt.colorbar(ax,ax=axes[2])
#     ax = axes[3].imshow(np.abs(samples[i,0] - data[7800+i, ind+1]))
#     plt.colorbar(ax,ax=axes[3])

# %%
# np.save(f"/home/meet/FlowMatchingTests/conditional-flow-matching/physics_flow_matching/wm_ar/exps/exp_{exp}/samples_{iteration}iter_7000_start_40", samples)
